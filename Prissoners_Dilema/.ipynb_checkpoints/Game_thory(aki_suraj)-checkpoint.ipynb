# %%
from numpy import random

# %% [markdown]
# akhilesh and suraj strategy

# %%
def akhilesh_suraj(oppIn = None):
    global akh_srj_d_cnt
    global akh_srj_c_cnt
    
    if (oppIn == None):
        akh_srj_d_cnt = 0
        akh_srj_c_cnt = 0

    if (akh_srj_d_cnt < 4):
        akh_srj_d_cnt += 1
        return "D"

    akh_srj_c_cnt += 1

    if (akh_srj_c_cnt % 2 == 0):
        akh_srj_d_cnt = 0

    return "C"

# %% [markdown]
# pankaj

# %%
flag_pankaj = False
counter_pankaj = 0

def pankaj(opp_move = None):
     global flag_pankaj
     global counter_pankaj

     if (opp_move == None):
          counter_pankaj = 0
          flag_pankaj = False
          return "C"

     if (counter_pankaj == 2):
          flag_pankaj = True
     
     if (flag_pankaj):
          return "D"

     if (opp_move == "C"):
          counter_pankaj = 0
          return "C"
     else:
          counter_pankaj += 1
          return "D"

counter_ar_init = 0
counter_ar_D = 0

def ar(opp_move = None):
     global counter_ar_init
     global counter_ar_D

     if (opp_move == None):
          counter_ar_init = 0
          counter_ar_D = 0

     counter_ar_init += 1
     if (counter_ar_init==1 or counter_ar_init ==2):
          return "D"
     if (counter_ar_init == 3):
          return "C"
     if (opp_move == "C" and counter_ar_D == 0):
          return "C"
     counter_ar_D += 1
     if (counter_ar_D == 3):
          counter_ar_D = 0
     return "D"

# %% [markdown]
# durgesh and nitin

# %%
counter_dn = 0

def dn(opp_move = None):
     global counter_dn

     if (opp_move == None):
          counter_dn = 0

     counter_dn += 1
     if(counter_dn==3):
          counter_dn=0
          if (opp_move == "C"):
               return "D"
          else:
               return "C"
     return "D"

# %% [markdown]
# aswini

# %%
flag_ash = False
counter_ash = -1
op_moves = []

def ash(opp_move = None):
  global flag_ash
  global counter_ash
  global op_moves

  if (opp_move == None):
    op_moves = []
    flag_ash = False
    counter_ash = -1
    return "D"
  else:
    op_moves.append(opp_move)
    if(len(op_moves) < 5):
            return "D"
    else:
      if((op_moves.count("C") > op_moves.count("D")) and (counter_ash==-1)):
        flag_ash=True
      

      if(flag_ash==True):
        #print("in True")
        counter_ash+=1
        if(counter_ash == 0):
          return "C"
        else:
          counter_ash=-1
          flag_ash=False
          return "D"
      else:
        #print("in False")
        counter_ash+=1
        if(counter_ash==1):
          counter_ash=-1
        return "D"

# %% [markdown]
# abhisek

# %%
def abhishek(oppIn = None):
         if(oppIn == None):
              i = counterAb([0])
         else:
              i = counterAb()
         tempCnt = i()
         lastEle = tempCnt[len(tempCnt)-1]
         tempCnt.append((lastEle)+1)
         cnt = counterAb(tempCnt)
         currCn = cnt()
         curCnt = currCn[len(currCn)-1]

         if (oppIn != None):
                 oppResponse = storeOpAb()
         else:
                 oppResponse = storeOpAb([])
                 
         tempOppResponse = oppResponse()
         tempOppResponse.append(oppIn)
         opResp = storeOpAb(tempOppResponse)
         curOverallResp = opResp()
         
         if (curCnt < 3):
                 return "D"
         else:
                 if "D" in curOverallResp[curCnt-3:curCnt]:
                         return "D"
                 else:
                         return "C"

# %% [markdown]
# roshan

# %%
def roshan(opp_move = None):
     cn = counter()
     if (opp_move == None):
          cn = counter([0])
     cn_temp = cn()
     i = cn_temp[len(cn_temp)-1]
     cn_temp.append(i+1)
     ct = counter(cn_temp)

     if  i == 0:
             my_move = "C"
             score_p([my_move])

     elif i > 0:

             my_moves = score_p()
             op_moves = score_o()

             if (opp_move == None):
                  my_moves = score_p([])
                  op_moves = score_o([])

             my_moves_list = my_moves()
             op_moves_list = op_moves()

             if (i == 1):
                 score_cal = score(my_moves_list, [opp_move])
             else:
                 score_cal = score(my_moves_list, op_moves_list)

             if opp_move == "C":
                 if  score_cal > 20:
                     my_move = "C"
                 elif score_cal == 0:
                         my_move = "D"
                 else:
                         my_move = "D"
             else :
                     my_move = "D"

             my_moves_list.append(my_move)
             op_moves_list.append(opp_move)
             my_m = score_p(my_moves_list)
             op_m = score_o(op_moves_list)

     return my_move

# %% [markdown]
# below few set of functions:
# 1. Random output
# 2. Tit-for-tat
# 3. Grudge
# 4. Our own(which will compete against others)
# 5. All C/All D

# %%
def tft(opponents_input = None):
     if (opponents_input == "D"):
         return "C"
     else:
         return "D"

def tft1(opponents_input = None):
     if (opponents_input == "C"):
         return "D"
     else:
         return "C"

def allC(opponents_input = None):
     return "C"

def allD(opponents_input = None):
     return "D"

def random1(oppIn = None):
     return random.choice(["C", "D"])

def storeOpAb(a = []):
     def closure():
         return (a)
     return closure

def storeOpAbI(a = []):
     def closure():
         return (a)
     return closure

def counterAb(i = [0]):
     def closure():
         return (i)
     return closure

def counterAbI(i = [0]):
     def closure():
         return (i)
     return closure

# %%
def counter(i=[0]):
     def closure():
         return (i)
     return closure

def score_p(i=[]):
     def closure():
         return (i)
     return closure

def score_o(i=[]):
     def closure():
         return (i)
     return closure


def score(my_input=None,op_input=None):
     my_counter = 0
     op_counter = 0
     for my_inp, op_inp in zip(my_input, op_input):
         if (my_inp == "C" and op_inp =="C"):
             my_counter = my_counter + 20
             op_counter = op_counter + 20
         elif (my_inp == "C" and op_inp =="D"):
             my_counter = my_counter + 0
             op_counter = op_counter + 30
         elif (my_inp == "D" and op_inp =="C"):
             my_counter = my_counter + 30
             op_counter = op_counter + 0
         elif (my_inp == "D" and op_inp =="D"):
             my_counter = my_counter + 10
             op_counter = op_counter + 10
     return(my_counter-op_counter)

# %%
############ Main Code ############

# %%
AVG = []

for i in range(1,16) :
    

    dispatcher = {'tft' : tft, 'tft1' : tft1, 'allC' : allC, 'allD' : allD, 'abhishek' : abhishek,
                  'random1' : random1, 'ash' : ash, 'dn' : dn, 'ar' : ar, 'pankaj' : pankaj,
                  'roshan' : roshan, 'akhilesh_suraj' : akhilesh_suraj}
    
    function_list = ['tft', 'tft1', 'allC', 'allD', 'abhishek', 'random1', 'ash', 'dn', 'ar',
                     'pankaj', 'roshan', 'akhilesh_suraj']

    def dispatch(name, *args, **kwargs):
         return dispatcher[name](*args, **kwargs)

    match_count = [0] * len(function_list)
    total_score = [0] * len(function_list)
    total_wins = [0] * len(function_list)
    total_tie =  [0] * len(function_list)

    match_counter = 0
    max_matches = i+1
    total_rounds = i+1
    total_matches = int((max_matches / 2) * len(function_list))
    max_matches = int(round((2 * total_matches) / len(function_list), 0))
    ind_max_match_count_reached = set()

    while(match_counter < total_matches):
             i = 0 #counter total rounds

             ind_max_match_count_reached.update([k for k in range(len(match_count)) if match_count[k] >= max_matches])

             if len(ind_max_match_count_reached) == len(function_list):
                 break

             functions_for_rand_selection = []
             functions_for_rand_selection.extend(function_list)
             if len(ind_max_match_count_reached) > 0:
                 for ind in ind_max_match_count_reached:
                     functions_for_rand_selection.remove(function_list[ind])
             flagCounter = 0
             while(True):
                  flagCounter += 1
                  randomly_selected_functions = random.choice(functions_for_rand_selection, size = (2))
                  if ((randomly_selected_functions[0] != randomly_selected_functions[1]) and not(('allD' in randomly_selected_functions) and ('abhishek' in randomly_selected_functions))):
                       break
                  elif ((match_counter > (total_matches * 0.98)) and flagCounter > 10):
                       break
                  elif (flagCounter > 10):
                       break
             if (flagCounter > 10):
                  break

             index_fun1 = function_list.index(randomly_selected_functions[0])
             index_fun2 = function_list.index(randomly_selected_functions[1])

             match_count[index_fun1] += 1
             match_count[index_fun2] += 1

             out1 = dispatch(randomly_selected_functions[0])
             out2 = dispatch(randomly_selected_functions[1])
             p1 = 0
             p2 = 0
             while(i < total_rounds):
                     if(out1 == out2 and out1 == "C"):
                             p1 = p1 + 20
                             p2 = p2 + 20
                     elif(out1 == out2 and out1 == "D"):
                             p1 = p1 + 10
                             p2 = p2 + 10
                     elif(out1 != out2 and out1 == "D"):
                             p1 = p1 + 30
                     else:
                             p2 = p2 + 30
                     out1T = dispatch(randomly_selected_functions[0], out2)
                     out2 = dispatch(randomly_selected_functions[1], out1)
                     out1 = out1T
                     i+=1

             total_score[index_fun1] += p1
             total_score[index_fun2] += p2
             if (p1 > p2):
                 total_wins[index_fun1] += 1
             elif (p2 > p1):
                 total_wins[index_fun2] += 1
             elif (p1 == p2):
                  total_tie[index_fun1] += 1
                  total_tie[index_fun2] += 1

             match_counter += 1

    avg_score = [x / y for x, y in zip(total_score, match_count)]
    

    print("Winner function is :", function_list[avg_score.index(max(avg_score))], "!!! and score of winner is :", round(max(avg_score), 3))

    print("\nAll scores:")
    print("Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score")
    for a, b, c, d, e in sorted(zip(function_list, match_count, avg_score, total_wins, total_tie), key = lambda x: x[2], reverse = True):
             print(b, " - ", round(c, 2), " - ", d, " - ", (round(d/b * 100, 2)) , " - ", e, " - ", a, " - ", (3*(d) + (e) + 2*(100-b)))

    AVG.append(avg_score)

print(AVG)
# Out:
# Winner function is : allD !!! and score of winner is : 50.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 2  -  50.0  -  2  -  100.0  -  0  -  allD  -  202
# 2  -  50.0  -  2  -  100.0  -  0  -  ash  -  202
# 2  -  50.0  -  2  -  100.0  -  0  -  akhilesh_suraj  -  202
# 2  -  30.0  -  1  -  50.0  -  1  -  dn  -  200
# 2  -  25.0  -  1  -  50.0  -  0  -  tft1  -  199
# 2  -  25.0  -  0  -  0.0  -  2  -  random1  -  198
# 2  -  20.0  -  0  -  0.0  -  1  -  tft  -  197
# 2  -  20.0  -  0  -  0.0  -  2  -  abhishek  -  198
# 2  -  20.0  -  0  -  0.0  -  2  -  ar  -  198
# 2  -  10.0  -  0  -  0.0  -  0  -  allC  -  196
# 2  -  10.0  -  0  -  0.0  -  0  -  pankaj  -  196
# 2  -  5.0  -  0  -  0.0  -  0  -  roshan  -  196
# Winner function is : tft !!! and score of winner is : 63.333
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 3  -  63.33  -  2  -  66.67  -  0  -  tft  -  200
# 3  -  56.67  -  2  -  66.67  -  1  -  abhishek  -  201
# 3  -  56.67  -  2  -  66.67  -  1  -  ash  -  201
# 3  -  50.0  -  2  -  66.67  -  1  -  allD  -  201
# 3  -  50.0  -  1  -  33.33  -  1  -  dn  -  198
# 3  -  50.0  -  2  -  66.67  -  1  -  akhilesh_suraj  -  201
# 3  -  40.0  -  1  -  33.33  -  1  -  ar  -  198
# 3  -  40.0  -  0  -  0.0  -  2  -  pankaj  -  196
# 3  -  30.0  -  0  -  0.0  -  1  -  roshan  -  195
# 3  -  20.0  -  1  -  33.33  -  0  -  tft1  -  197
# 3  -  20.0  -  0  -  0.0  -  1  -  allC  -  195
# 3  -  10.0  -  0  -  0.0  -  0  -  random1  -  194
# Winner function is : allD !!! and score of winner is : 80.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 4  -  80.0  -  3  -  75.0  -  1  -  allD  -  202
# 4  -  80.0  -  3  -  75.0  -  1  -  abhishek  -  202
# 4  -  72.5  -  3  -  75.0  -  0  -  dn  -  201
# 4  -  57.5  -  2  -  50.0  -  0  -  tft  -  198
# 4  -  55.0  -  3  -  75.0  -  1  -  ash  -  202
# 4  -  55.0  -  0  -  0.0  -  3  -  pankaj  -  195
# 4  -  55.0  -  2  -  50.0  -  2  -  akhilesh_suraj  -  200
# 4  -  50.0  -  0  -  0.0  -  1  -  roshan  -  193
# 4  -  42.5  -  1  -  25.0  -  1  -  tft1  -  196
# 4  -  40.0  -  1  -  25.0  -  1  -  random1  -  196
# 4  -  35.0  -  0  -  0.0  -  0  -  allC  -  192
# 4  -  35.0  -  0  -  0.0  -  1  -  ar  -  193
# Winner function is : abhishek !!! and score of winner is : 98.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 5  -  98.0  -  5  -  100.0  -  0  -  abhishek  -  205
# 5  -  94.0  -  3  -  60.0  -  2  -  allD  -  201
# 5  -  82.0  -  2  -  40.0  -  2  -  random1  -  198
# 3  -  80.0  -  0  -  0.0  -  1  -  pankaj  -  195
# 5  -  80.0  -  2  -  40.0  -  2  -  akhilesh_suraj  -  198
# 5  -  78.0  -  3  -  60.0  -  1  -  dn  -  200
# 5  -  74.0  -  2  -  40.0  -  0  -  tft  -  196
# 5  -  62.0  -  3  -  60.0  -  2  -  ash  -  201
# 5  -  62.0  -  2  -  40.0  -  0  -  ar  -  196
# 5  -  60.0  -  0  -  0.0  -  2  -  allC  -  192
# 5  -  54.0  -  0  -  0.0  -  2  -  roshan  -  192
# 5  -  24.0  -  0  -  0.0  -  0  -  tft1  -  190
# Winner function is : ash !!! and score of winner is : 128.333
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 6  -  128.33  -  6  -  100.0  -  0  -  ash  -  206
# 6  -  123.33  -  6  -  100.0  -  0  -  allD  -  206
# 6  -  120.0  -  3  -  50.0  -  2  -  dn  -  199
# 6  -  106.67  -  3  -  50.0  -  1  -  akhilesh_suraj  -  198
# 6  -  100.0  -  6  -  100.0  -  0  -  abhishek  -  206
# 6  -  78.33  -  0  -  0.0  -  3  -  roshan  -  191
# 6  -  76.67  -  3  -  50.0  -  0  -  random1  -  197
# 6  -  71.67  -  1  -  16.67  -  2  -  pankaj  -  193
# 6  -  70.0  -  1  -  16.67  -  3  -  ar  -  194
# 6  -  66.67  -  1  -  16.67  -  0  -  tft  -  191
# 6  -  36.67  -  0  -  0.0  -  1  -  allC  -  189
# 6  -  25.0  -  0  -  0.0  -  0  -  tft1  -  188
# Winner function is : dn !!! and score of winner is : 132.857
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 7  -  132.86  -  5  -  71.43  -  1  -  dn  -  202
# 7  -  127.14  -  6  -  85.71  -  1  -  allD  -  205
# 7  -  118.57  -  5  -  71.43  -  2  -  ash  -  203
# 7  -  102.86  -  4  -  57.14  -  1  -  ar  -  199
# 7  -  101.43  -  4  -  57.14  -  0  -  akhilesh_suraj  -  198
# 7  -  100.0  -  3  -  42.86  -  0  -  tft1  -  195
# 7  -  98.57  -  6  -  85.71  -  1  -  abhishek  -  205
# 7  -  91.43  -  2  -  28.57  -  1  -  pankaj  -  193
# 7  -  91.43  -  0  -  0.0  -  2  -  roshan  -  188
# 7  -  60.0  -  0  -  0.0  -  2  -  allC  -  188
# 7  -  60.0  -  1  -  14.29  -  0  -  random1  -  189
# 7  -  52.86  -  0  -  0.0  -  1  -  tft  -  187
# Winner function is : akhilesh_suraj !!! and score of winner is : 172.5
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 8  -  172.5  -  7  -  87.5  -  0  -  akhilesh_suraj  -  205
# 8  -  145.0  -  3  -  37.5  -  3  -  dn  -  196
# 6  -  140.0  -  6  -  100.0  -  0  -  allD  -  206
# 4  -  135.0  -  3  -  75.0  -  1  -  abhishek  -  202
# 8  -  125.0  -  7  -  87.5  -  1  -  ash  -  206
# 8  -  120.0  -  4  -  50.0  -  3  -  ar  -  199
# 8  -  110.0  -  2  -  25.0  -  2  -  tft  -  192
# 8  -  108.75  -  2  -  25.0  -  2  -  random1  -  192
# 8  -  105.0  -  3  -  37.5  -  1  -  pankaj  -  194
# 8  -  98.75  -  0  -  0.0  -  2  -  roshan  -  186
# 8  -  50.0  -  0  -  0.0  -  1  -  allC  -  185
# 8  -  46.25  -  0  -  0.0  -  0  -  tft1  -  184
# Winner function is : tft !!! and score of winner is : 154.444
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 9  -  154.44  -  5  -  55.56  -  0  -  tft  -  197
# 9  -  150.0  -  7  -  77.78  -  2  -  ash  -  205
# 9  -  138.89  -  8  -  88.89  -  1  -  abhishek  -  207
# 9  -  134.44  -  3  -  33.33  -  2  -  akhilesh_suraj  -  193
# 7  -  134.29  -  3  -  42.86  -  1  -  pankaj  -  196
# 9  -  133.33  -  3  -  33.33  -  2  -  dn  -  193
# 9  -  118.89  -  8  -  88.89  -  1  -  allD  -  207
# 9  -  108.89  -  0  -  0.0  -  3  -  roshan  -  185
# 9  -  107.78  -  3  -  33.33  -  1  -  random1  -  192
# 9  -  106.67  -  2  -  22.22  -  1  -  tft1  -  189
# 9  -  97.78  -  3  -  33.33  -  1  -  ar  -  192
# 9  -  51.11  -  0  -  0.0  -  1  -  allC  -  183
# Winner function is : allD !!! and score of winner is : 186.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 10  -  186.0  -  9  -  90.0  -  1  -  allD  -  208
# 10  -  179.0  -  6  -  60.0  -  1  -  dn  -  199
# 10  -  167.0  -  7  -  70.0  -  3  -  abhishek  -  204
# 10  -  164.0  -  6  -  60.0  -  1  -  akhilesh_suraj  -  199
# 10  -  144.0  -  4  -  40.0  -  3  -  pankaj  -  195
# 10  -  141.0  -  3  -  30.0  -  0  -  tft  -  189
# 10  -  130.0  -  6  -  60.0  -  4  -  ash  -  202
# 10  -  129.0  -  6  -  60.0  -  1  -  ar  -  199
# 10  -  127.0  -  0  -  0.0  -  2  -  roshan  -  182
# 10  -  108.0  -  0  -  0.0  -  2  -  allC  -  182
# 8  -  81.25  -  1  -  12.5  -  0  -  random1  -  187
# 10  -  78.0  -  2  -  20.0  -  0  -  tft1  -  186
# Winner function is : allD !!! and score of winner is : 190.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 8  -  190.0  -  6  -  75.0  -  2  -  allD  -  204
# 11  -  185.45  -  0  -  0.0  -  8  -  roshan  -  186
# 11  -  185.45  -  7  -  63.64  -  0  -  akhilesh_suraj  -  199
# 11  -  182.73  -  5  -  45.45  -  3  -  pankaj  -  196
# 11  -  181.82  -  4  -  36.36  -  0  -  dn  -  190
# 8  -  177.5  -  8  -  100.0  -  0  -  abhishek  -  208
# 11  -  170.91  -  9  -  81.82  -  2  -  ash  -  207
# 11  -  151.82  -  6  -  54.55  -  1  -  ar  -  197
# 11  -  129.09  -  3  -  27.27  -  2  -  tft  -  189
# 11  -  114.55  -  1  -  9.09  -  1  -  random1  -  182
# 11  -  103.64  -  0  -  0.0  -  3  -  allC  -  181
# 11  -  98.18  -  3  -  27.27  -  0  -  tft1  -  187
# Winner function is : allD !!! and score of winner is : 245.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 12  -  245.0  -  12  -  100.0  -  0  -  allD  -  212
# 12  -  226.67  -  6  -  50.0  -  0  -  dn  -  194
# 12  -  203.33  -  6  -  50.0  -  2  -  random1  -  196
# 12  -  193.33  -  12  -  100.0  -  0  -  abhishek  -  212
# 12  -  180.0  -  12  -  100.0  -  0  -  ash  -  212
# 12  -  173.33  -  10  -  83.33  -  0  -  ar  -  206
# 12  -  139.17  -  0  -  0.0  -  5  -  roshan  -  181
# 12  -  135.83  -  2  -  16.67  -  1  -  pankaj  -  183
# 12  -  131.67  -  2  -  16.67  -  2  -  tft  -  184
# 12  -  126.67  -  2  -  16.67  -  2  -  akhilesh_suraj  -  184
# 12  -  108.33  -  1  -  8.33  -  1  -  tft1  -  180
# 12  -  78.33  -  0  -  0.0  -  1  -  allC  -  177
# Winner function is : tft !!! and score of winner is : 228.462
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 13  -  228.46  -  6  -  46.15  -  0  -  tft  -  192
# 10  -  218.0  -  9  -  90.0  -  1  -  allD  -  208
# 12  -  211.67  -  10  -  83.33  -  2  -  abhishek  -  208
# 13  -  206.92  -  3  -  23.08  -  8  -  pankaj  -  191
# 13  -  191.54  -  10  -  76.92  -  3  -  ash  -  207
# 13  -  188.46  -  8  -  61.54  -  2  -  ar  -  200
# 13  -  186.92  -  0  -  0.0  -  6  -  roshan  -  180
# 13  -  176.15  -  5  -  38.46  -  0  -  dn  -  189
# 13  -  173.08  -  6  -  46.15  -  0  -  akhilesh_suraj  -  192
# 13  -  152.31  -  2  -  15.38  -  1  -  random1  -  181
# 13  -  137.69  -  4  -  30.77  -  1  -  tft1  -  187
# 13  -  124.62  -  0  -  0.0  -  2  -  allC  -  176
# Winner function is : allD !!! and score of winner is : 287.143
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 14  -  287.14  -  13  -  92.86  -  1  -  allD  -  212
# 14  -  247.14  -  9  -  64.29  -  0  -  dn  -  199
# 14  -  240.0  -  12  -  85.71  -  2  -  abhishek  -  210
# 14  -  231.43  -  8  -  57.14  -  1  -  pankaj  -  197
# 14  -  224.29  -  11  -  78.57  -  3  -  ash  -  208
# 14  -  203.57  -  12  -  85.71  -  0  -  ar  -  208
# 14  -  177.14  -  0  -  0.0  -  2  -  roshan  -  174
# 14  -  170.0  -  5  -  35.71  -  0  -  akhilesh_suraj  -  187
# 14  -  155.0  -  5  -  35.71  -  0  -  tft  -  187
# 14  -  152.14  -  3  -  21.43  -  0  -  random1  -  181
# 14  -  122.86  -  0  -  0.0  -  1  -  allC  -  173
# 14  -  106.43  -  1  -  7.14  -  0  -  tft1  -  175
# Winner function is : allD !!! and score of winner is : 294.615
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 13  -  294.62  -  12  -  92.31  -  1  -  allD  -  211
# 15  -  258.0  -  13  -  86.67  -  2  -  abhishek  -  211
# 15  -  256.67  -  6  -  40.0  -  6  -  pankaj  -  194
# 15  -  234.0  -  7  -  46.67  -  3  -  dn  -  194
# 15  -  225.33  -  12  -  80.0  -  3  -  ash  -  209
# 15  -  217.33  -  11  -  73.33  -  2  -  ar  -  205
# 15  -  195.33  -  0  -  0.0  -  7  -  roshan  -  177
# 15  -  195.33  -  4  -  26.67  -  1  -  akhilesh_suraj  -  183
# 15  -  192.0  -  3  -  20.0  -  2  -  random1  -  181
# 15  -  180.0  -  0  -  0.0  -  4  -  allC  -  174
# 15  -  163.33  -  1  -  6.67  -  3  -  tft  -  176
# 15  -  105.33  -  3  -  20.0  -  0  -  tft1  -  179
# Winner function is : allD !!! and score of winner is : 310.0
#
# All scores:
# Matches Played - Average Score - Total Wins - % wins - Total Tie - Function - Score
# 16  -  310.0  -  15  -  93.75  -  1  -  allD  -  214
# 16  -  249.38  -  12  -  75.0  -  4  -  abhishek  -  208
# 16  -  246.88  -  9  -  56.25  -  5  -  pankaj  -  200
# 16  -  233.75  -  11  -  68.75  -  5  -  ash  -  206
# 16  -  233.75  -  8  -  50.0  -  0  -  akhilesh_suraj  -  192
# 16  -  230.62  -  5  -  31.25  -  2  -  tft  -  185
# 16  -  227.5  -  5  -  31.25  -  0  -  random1  -  183
# 16  -  221.25  -  0  -  0.0  -  7  -  roshan  -  175
# 16  -  217.5  -  9  -  56.25  -  2  -  ar  -  197
# 16  -  175.62  -  3  -  18.75  -  1  -  tft1  -  178
# 16  -  173.75  -  5  -  31.25  -  0  -  dn  -  183
# 16  -  95.0  -  0  -  0.0  -  1  -  allC  -  169
# [[20.0, 25.0, 10.0, 50.0, 20.0, 25.0, 50.0, 30.0, 20.0, 10.0, 5.0, 50.0], [63.333333333333336, 20.0, 20.0, 50.0, 56.666666666666664, 10.0, 56.666666666666664, 50.0, 40.0, 40.0, 30.0, 50.0], [57.5, 42.5, 35.0, 80.0, 80.0, 40.0, 55.0, 72.5, 35.0, 55.0, 50.0, 55.0], [74.0, 24.0, 60.0, 94.0, 98.0, 82.0, 62.0, 78.0, 62.0, 80.0, 54.0, 80.0], [66.66666666666667, 25.0, 36.666666666666664, 123.33333333333333, 100.0, 76.66666666666667, 128.33333333333334, 120.0, 70.0, 71.66666666666667, 78.33333333333333, 106.66666666666667], [52.857142857142854, 100.0, 60.0, 127.14285714285714, 98.57142857142857, 60.0, 118.57142857142857, 132.85714285714286, 102.85714285714286, 91.42857142857143, 91.42857142857143, 101.42857142857143], [110.0, 46.25, 50.0, 140.0, 135.0, 108.75, 125.0, 145.0, 120.0, 105.0, 98.75, 172.5], [154.44444444444446, 106.66666666666667, 51.111111111111114, 118.88888888888889, 138.88888888888889, 107.77777777777777, 150.0, 133.33333333333334, 97.77777777777777, 134.28571428571428, 108.88888888888889, 134.44444444444446], [141.0, 78.0, 108.0, 186.0, 167.0, 81.25, 130.0, 179.0, 129.0, 144.0, 127.0, 164.0], [129.0909090909091, 98.18181818181819, 103.63636363636364, 190.0, 177.5, 114.54545454545455, 170.9090909090909, 181.8181818181818, 151.8181818181818, 182.72727272727272, 185.45454545454547, 185.45454545454547], [131.66666666666666, 108.33333333333333, 78.33333333333333, 245.0, 193.33333333333334, 203.33333333333334, 180.0, 226.66666666666666, 173.33333333333334, 135.83333333333334, 139.16666666666666, 126.66666666666667], [228.46153846153845, 137.69230769230768, 124.61538461538461, 218.0, 211.66666666666666, 152.30769230769232, 191.53846153846155, 176.15384615384616, 188.46153846153845, 206.92307692307693, 186.92307692307693, 173.07692307692307], [155.0, 106.42857142857143, 122.85714285714286, 287.14285714285717, 240.0, 152.14285714285714, 224.28571428571428, 247.14285714285714, 203.57142857142858, 231.42857142857142, 177.14285714285714, 170.0], [163.33333333333334, 105.33333333333333, 180.0, 294.61538461538464, 258.0, 192.0, 225.33333333333334, 234.0, 217.33333333333334, 256.6666666666667, 195.33333333333334, 195.33333333333334], [230.625, 175.625, 95.0, 310.0, 249.375, 227.5, 233.75, 173.75, 217.5, 246.875, 221.25, 233.75]]
